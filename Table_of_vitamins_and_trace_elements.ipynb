# %%
import pandas as pd
import numpy as np

# Создание данных для DataFrame
data = {
    'Продукт': [
        'Грецкие орехи 100 гр', 'Кешью 100 гр', 'Авокадо 100 гр', 'Киви 100 гр', 
        'Ядро кедрового ореха 100 гр', 'Яйцо 1 шт.', 'Говядина 100 гр', 'Свинина 100 гр', 
        'Баранина 100 гр', 'Лосось 100 гр', 'Куриная грудка 100 гр', 'Грудка индейки 100 гр', 
        'Сельдерей 100 гр', 'Огурцы 1 шт.', 'Помидоры 1 шт.'
    ],
    'Калории на 100 гр продукта': [
        654, 553, 160, 61, 673, 68, 250, 260, 
        294, 208, 165, 135, 16, 10, 18
    ],
    'Белки (г)': [
        15, 18, 2, 1.14, 13.7, 6, 26, 25, 
        25, 20, 31, 29, 0.7, 0.65, 0.88
    ],
    'Жиры (г)': [
        65, 44, 15, 0.52, 68.4, 4.75, 15, 21, 
        24, 13, 3.6, 0.7, 0.17, 0.11, 0.2
    ],
    'Углеводы (г)': [
        14, 30, 9, 14.66, 13.1, 0.36, 0, 0, 
        0, 0, 0, 0, 1.9, 1.8, 3.9
    ],
    'Клетчатка (г)': [
        6.7, 3.3, 6.7, 3, 3.7, 0, 0, 0, 
        0, 0, 0, 0, 1.6, 0.5, 1.2
    ],
    'Витамин C (мг)': [
        1.3, 0.5, 10, 92.7, 0.8, 0, 0, 0, 
        0, 0, 0, 0, 3.1, 2.8, 12.7
    ],
    'Калий (мг)': [
        441, 660, 485, 312, 597, 69, 350, 340, 
        370, 363, 256, 237, 260, 140, 237
    ],
    'Магний (мг)': [
        158, 292, 29, 17, 251, 6, 21, 19, 
        22, 25, 25, 23, 11, 7, 11
    ]
}

# Создание DataFrame
df = pd.DataFrame(data)

# Добавление колонок "Итого" с пустыми значениями
df['Итого Калории'] = np.nan
df['Итого Белки'] = np.nan
df['Итого Жиры'] = np.nan
df['Итого Углеводы'] = np.nan
df['Итого Клетчатка'] = np.nan          
df['Итого Витамин C'] = np.nan
df['Итого Калий'] = np.nan
df['Итого Магний'] = np.nan

# Сохранение DataFrame в файл Excel
df.to_excel("nutrition_data.xlsx", index=False)

df  # Показать DataFrame
# Out:
#                         Продукт  Калории на 100 гр продукта  Белки (г)  \
# 0          Грецкие орехи 100 гр                         654      15.00
# 1                  Кешью 100 гр                         553      18.00
# 2                Авокадо 100 гр                         160       2.00
# 3                   Киви 100 гр                          61       1.14
# 4   Ядро кедрового ореха 100 гр                         673      13.70
# 5                    Яйцо 1 шт.                          68       6.00
# 6               Говядина 100 гр                         250      26.00
# 7                Свинина 100 гр                         260      25.00
# 8               Баранина 100 гр                         294      25.00
# 9                 Лосось 100 гр                         208      20.00
# 10        Куриная грудка 100 гр                         165      31.00
# 11        Грудка индейки 100 гр                         135      29.00
# ...

# %%
# Получим информацию о типах данных и количестве непустых значений
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Продукт                     15 non-null     object
#  1   Калории на 100 гр продукта  15 non-null     int64
#  2   Белки (г)                   15 non-null     float64
#  3   Жиры (г)                    15 non-null     float64
#  4   Углеводы (г)                15 non-null     float64
#  5   Клетчатка (г)               15 non-null     float64
#  6   Витамин C (мг)              15 non-null     float64
#  7   Калий (мг)                  15 non-null     int64
#  8   Магний (мг)                 15 non-null     int64
#  9   Итого Калории               0 non-null      float64
#  10  Итого Белки                 0 non-null      float64
#  11  Итого Жиры                  0 non-null      float64
#  12  Итого Углеводы              0 non-null      float64
# ...

# %%
# Описательные статистики для количественных переменных
df.describe()
# Out:
#        Калории на 100 гр продукта  Белки (г)   Жиры (г)  Углеводы (г)  \
# count                   15.000000  15.000000  15.000000     15.000000
# mean                   235.000000  14.271333  18.363333      5.914667
# std                    223.279773  11.503453  23.074017      8.705359
# min                     10.000000   0.650000   0.110000      0.000000
# 25%                     64.500000   1.570000   0.610000      0.000000
# 50%                    165.000000  15.000000  13.000000      1.800000
# 75%                    277.000000  25.000000  22.500000     11.050000
# max                    673.000000  31.000000  68.400000     30.000000
#
#        Клетчатка (г)  Витамин C (мг)  Калий (мг)  Магний (мг)  Итого Калории  \
# count      15.000000        15.00000   15.000000    15.000000            0.0
# mean        1.780000         8.26000  341.133333    61.133333            NaN
# std         2.391712        23.68121  158.132795    93.232326            NaN
# ...

# %%
# Проверка на наличие пропущенных значений
df.isnull().sum()
# Out:
# Продукт                        0
# Калории на 100 гр продукта     0
# Белки (г)                      0
# Жиры (г)                       0
# Углеводы (г)                   0
# Клетчатка (г)                  0
# Витамин C (мг)                 0
# Калий (мг)                     0
# Магний (мг)                    0
# Итого Калории                 15
# Итого Белки                   15
# Итого Жиры                    15
# Итого Углеводы                15
# Итого Клетчатка               15
# Итого Витамин C               15
# Итого Калий                   15
# Итого Магний                  15
# dtype: int64

# %%
# Общее количество записей в датафрейме
df.shape
# Out:
# (15, 17)
